# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
import os

# %%
my_file= r"C:\Users\Laptop\Documents\covid_19_clean_complete.csv"

# %%
os.path.exists(my_file)
# Out:
# True

# %%
df= pd.read_csv(r"C:\Users\Laptop\Documents\covid_19_clean_complete.csv")
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
df=df.drop(columns="Province/State")

# %%
df
# Out:
#               Country/Region        Lat       Long        Date  Confirmed  \
# 0                Afghanistan  33.939110  67.709953  2020-01-22          0
# 1                    Albania  41.153300  20.168300  2020-01-22          0
# 2                    Algeria  28.033900   1.659600  2020-01-22          0
# 3                    Andorra  42.506300   1.521800  2020-01-22          0
# 4                     Angola -11.202700  17.873900  2020-01-22          0
# ...                      ...        ...        ...         ...        ...
# 49063  Sao Tome and Principe   0.186400   6.613100  2020-07-27        865
# 49064                  Yemen  15.552727  48.516388  2020-07-27       1691
# 49065                Comoros -11.645500  43.333300  2020-07-27        354
# 49066             Tajikistan  38.861000  71.276100  2020-07-27       7235
# 49067                Lesotho -29.610000  28.233600  2020-07-27        505
#
#        Deaths  Recovered  Active             WHO Region
# ...

# %%
df.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  49068 non-null  object
#  1   Lat             49068 non-null  float64
#  2   Long            49068 non-null  float64
#  3   Date            49068 non-null  object
#  4   Confirmed       49068 non-null  int64
#  5   Deaths          49068 non-null  int64
#  6   Recovered       49068 non-null  int64
#  7   Active          49068 non-null  int64
#  8   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 3.4+ MB

# %%
df.isnull().sum()
# Out:
# Country/Region    0
# Lat               0
# Long              0
# Date              0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# WHO Region        0
# dtype: int64

# %%
df.nunique()
# Out:
# Country/Region      187
# Lat                 260
# Long                261
# Date                188
# Confirmed         10861
# Deaths             3640
# Recovered          7609
# Active             8641
# WHO Region            6
# dtype: int64

# %%
df.sort_values(by="Deaths",ascending=False).head()

# %%
columns_to_work_with= ['Lat','Long','Confirmed','Deaths','Recovered','Active']

# %%
df[columns_to_work_with].corrwith(df[columns_to_work_with])
# Out:
# Lat          1.0
# Long         1.0
# Confirmed    1.0
# Deaths       1.0
# Recovered    1.0
# Active       1.0
# dtype: float64

# %%
df[columns_to_work_with].mean()
# Out:
# Lat             21.433730
# Long            23.528236
# Confirmed    16884.904255
# Deaths         884.179160
# Recovered     7915.713479
# Active        8085.011617
# dtype: float64

# %%
mean_df=df.groupby("Country/Region")[columns_to_work_with].mean().reset_index()

# %%
mean_df.sort_values(by="Confirmed",ascending = False)
# Out:
#             Country/Region        Lat        Long     Confirmed        Deaths  \
# 173                     US  40.000000 -100.000000  1.193330e+06  58571.335106
# 23                  Brazil -14.235000  -51.925300  4.761966e+05  20946.989362
# 138                 Russia  61.524010  105.318756  2.415341e+05   3294.601064
# 79                   India  20.593684   78.962880  2.174652e+05   5913.994681
# 157                  Spain  40.463667   -3.749220  1.457662e+05  16133.138298
# ..                     ...        ...         ...           ...           ...
# 140  Saint Kitts and Nevis  17.357822  -62.782998  9.425532e+00      0.000000
# 68               Greenland  71.706900  -42.604300  8.015957e+00      0.000000
# 75                Holy See  41.902900   12.453400  7.212766e+00      0.000000
# 130       Papua New Guinea  -6.314993  143.955550  6.303191e+00      0.010638
# 183         Western Sahara  24.215500  -12.885800  4.792553e+00      0.335106
#
# ...

# %%
df
# Out:
#               Country/Region        Lat       Long        Date  Confirmed  \
# 0                Afghanistan  33.939110  67.709953  2020-01-22          0
# 1                    Albania  41.153300  20.168300  2020-01-22          0
# 2                    Algeria  28.033900   1.659600  2020-01-22          0
# 3                    Andorra  42.506300   1.521800  2020-01-22          0
# 4                     Angola -11.202700  17.873900  2020-01-22          0
# ...                      ...        ...        ...         ...        ...
# 49063  Sao Tome and Principe   0.186400   6.613100  2020-07-27        865
# 49064                  Yemen  15.552727  48.516388  2020-07-27       1691
# 49065                Comoros -11.645500  43.333300  2020-07-27        354
# 49066             Tajikistan  38.861000  71.276100  2020-07-27       7235
# 49067                Lesotho -29.610000  28.233600  2020-07-27        505
#
#        Deaths  Recovered  Active             WHO Region
# ...

# %%
df_deaths=mean_df.sort_values(by="Deaths",ascending = False)
df_deaths
# Out:
#     Country/Region        Lat        Long     Confirmed        Deaths  \
# 173             US  40.000000 -100.000000  1.193330e+06  58571.335106
# 23          Brazil -14.235000  -51.925300  4.761966e+05  20946.989362
# 85           Italy  41.871940   12.567380  1.422614e+05  19721.898936
# 157          Spain  40.463667   -3.749220  1.457662e+05  16133.138298
# 111         Mexico  23.634500 -102.552800  7.950107e+04   9192.962766
# ..             ...        ...         ...           ...           ...
# 19          Bhutan  27.514200   90.433600  2.644149e+01      0.000000
# 114       Mongolia  46.862500  103.846700  9.042021e+01      0.000000
# 168    Timor-Leste  -8.874217  125.727539  1.322872e+01      0.000000
# 148     Seychelles  -4.679600   55.492000  2.115426e+01      0.000000
# 68       Greenland  71.706900  -42.604300  8.015957e+00      0.000000
#
#          Recovered         Active
# 173  299752.212766  835005.962766
# 23   289855.707447  165393.936170
# ...

# %%
df_my_transpose=df.transpose()
# Out:
#                                 0           1           2           3      \
# Country/Region            Afghanistan     Albania     Algeria     Andorra
# Lat                          33.93911     41.1533     28.0339     42.5063
# Long                        67.709953     20.1683      1.6596      1.5218
# Date                       2020-01-22  2020-01-22  2020-01-22  2020-01-22
# Confirmed                           0           0           0           0
# Deaths                              0           0           0           0
# Recovered                           0           0           0           0
# Active                              0           0           0           0
# WHO Region      Eastern Mediterranean      Europe      Africa      Europe
#
#                      4                    5           6           7      \
# Country/Region      Angola  Antigua and Barbuda   Argentina     Armenia
# Lat               -11.2027              17.0608    -38.4161     40.0691
# ...

# %% [markdown]
# mean_df

# %%
mean_df_new=mean_df.set_index("Country/Region")

# %%
mean_df_new.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Country/Region'>

# %%
mean_transposed=mean_df.transpose()

# %%
mean_transposed
# Out:
#                          0            1            2           3    \
# Country/Region   Afghanistan      Albania      Algeria     Andorra
# Lat                 33.93911      41.1533      28.0339     42.5063
# Long               67.709953      20.1683       1.6596      1.5218
# Confirmed       10299.946809  1046.287234  6275.292553  502.148936
# Deaths            261.159574    30.361702   414.744681   28.845745
# Recovered        4245.957447   632.324468  4020.728723  367.414894
# Active           5792.829787   383.601064  1839.819149  105.888298
#
#                        4                    5             6            7    \
# Country/Region      Angola  Antigua and Barbuda     Argentina      Armenia
# Lat               -11.2027              17.0608      -38.4161      40.0691
# Long               17.8739             -61.7964      -63.6167      45.0382
# Confirmed       120.542553            23.867021  23673.712766  8442.409574
# ...
